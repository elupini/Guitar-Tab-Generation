# %%
import pandas as pd
import lib.helper_functions as hf
import os
import jams
import numpy as np
from matplotlib import lines as mlines, pyplot as plt

# %% [markdown]
# # Guitar Tab Generation - Algorithmic Predictions

# %%
# Data is contained in directory 'data' after unzipping the data.zip file
directory = 'data'

# %% [markdown]
# #### Baseline

# %%
baseline_avg_score, baseline_avg_cost = hf.baseline_experiment(directory)
# Out:
# /Users/elupini/Repos/Guitar_Tab_Generation/lib/helper_functions.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['prediction'] = df.apply(lambda x: baseline_helper(x.midi_note), axis=1)

# %%
print('Results')
print('--------')
print('Average Score: ',baseline_avg_score)
print('Average Distance: ',baseline_avg_cost)
# Out:
# Results
# --------
# Average Score:  0.2991130206081085
# Average Distance:  136.79444444444445

# %% [markdown]
# #### Naive Shortest Distance Model

# %%
naive_dist_score, naive_dist_cost = hf.naive_shortest_distance(directory)
# Out:
# /Users/elupini/Repos/Guitar_Tab_Generation/lib/helper_functions.py:163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['string'] = strings['string_pred']

# %%
print('Results')
print('--------')
print('Average Score: ',naive_dist_score)
print('Average Distance: ',naive_dist_cost)
# Out:
# Results
# --------
# Average Score:  0.3073793304384058
# Average Distance:  111.27222222222223

# %% [markdown]
# #### Smart Shortest Distance Model

# %%
smart_dist_score, smart_dist_cost = hf.shortest_distance_experiment(directory)
# Out:
# /Users/elupini/Repos/Guitar_Tab_Generation/lib/helper_functions.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['string'] = strings['string_pred']
# /Users/elupini/Repos/Guitar_Tab_Generation/lib/helper_functions.py:342: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['fret_position'] = frets['fret_pred']

# %%
print('Results')
print('--------')
print('Average Score: ',smart_dist_score)
print('Average Distance: ',smart_dist_cost)
# Out:
# Results
# --------
# Average Score:  0.4440196496398494
# Average Distance:  156.41666666666666

# %% [markdown]
# #### Visualization and Single Track Prediction

# %%
filepath = 'data/01_BN3-154-E_solo.jams'
# Predict Tab for Single Track
prediction = hf.predict_shortest_distance('data/01_BN3-154-E_solo.jams')
# Visualize a window of the tab
hf.tabularize_result(filepath,prediction,window=(0,5))
